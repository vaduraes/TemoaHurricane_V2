# %%
import numpy as np 
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import sqlite3
import sqlalchemy
from tqdm import tqdm


PathStochastic="./StochasticFiles/"
SqliteNamesStochastic={"Stochastic (Hurricane)": "NC_EnergySystem2023.sqlite",
                       "Deterministic (No Hurricane)":"NC_EnergySystem2023_D.sqlite"}

SqliteNamesDeterministic={"Deterministic (No Hurricane)":"NC_EnergySystem2023_D.sqlite"}

###############################################################################################################
#### Outputs from the sqlite files we are interested


# OutputSqlTables={"Output_CapacityByPeriodAndTech":"",
#                  "Output_Costs":"",
#                  "Output_Curtailment":"",
#                  "Output_Duals":"",
#                  "Output_Emissions":"",
#                  "Output_Objective":"",
#                  "Output_VFlow_In":"",
#                  "Output_VFlow_Out":"",
#                  "Output_V_Capacity":""}

OutputSqlTables={"Output_CapacityByPeriodAndTech":[],
                 "Output_Emissions":[],
                 "Output_VFlow_Out":[]}

# %% [markdown]
# # Read sqlite files stochastic

# %%
for simulation in tqdm(list(SqliteNamesStochastic.keys())):
    SqliteName=SqliteNamesStochastic[simulation]

    SqlitePath=PathStochastic+SqliteName
    
    for table_name in list(OutputSqlTables.keys()):
        engine = sqlalchemy.create_engine("sqlite:///%s" % SqlitePath, execution_options={"sqlite_raw_colnames": True})

        df = pd.read_sql_table(table_name, engine)

        OutputSqlTables[table_name].append(df)
# Out:
# 100%|██████████| 2/2 [00:51<00:00, 25.91s/it]

# %%
OutputSqlTables_D={"Output_CapacityByPeriodAndTech":[],
                 "Output_Emissions":[],
                 "Output_VFlow_Out":[]}


for simulation in tqdm(list(SqliteNamesDeterministic.keys())):
    SqliteName=SqliteNamesDeterministic[simulation]

    SqlitePath=PathStochastic+SqliteName
    
    for table_name in list(OutputSqlTables_D.keys()):
        engine = sqlalchemy.create_engine("sqlite:///%s" % SqlitePath, execution_options={"sqlite_raw_colnames": True})

        df = pd.read_sql_table(table_name, engine)

        OutputSqlTables_D[table_name].append(df)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 14.69it/s]

# %% [markdown]
# # Define group of technologies we may want to plot

# %%
TechAtGroups={ "Biomass_CCS":["BIOMASS_CC90_NEW"],

                "NaturalGas_Non_CCS":["NG_CC_EX_NO_RFIT","NG_GT_EX_NO_RFIT","NG_F-FRAME_CC_NEW_NO_RFIT","NG_F-FRAME_CT_NEW_NO_RFIT","NG_H-FRAME_CC_NEW_NO_RFIT","NG_ST_EXISTING"],
                
                "NaturalGas_ALL":["NG_CC_EX_NO_RFIT","NG_GT_EX_NO_RFIT","NG_F-FRAME_CC_NEW_NO_RFIT","NG_F-FRAME_CT_NEW_NO_RFIT","NG_H-FRAME_CC_NEW_NO_RFIT","NG_ST_EXISTING",
                              "NG_F-FRAME_CC_95CC_NEW","NG_H-FRAME_CC_95CC_NEW","NG_F-FRAME_CC_97CC_NEW",
                              "NG_H-FRAME_CC_97CC_NEW","NG_CC_EX_RFIT","NG_GT_EX_RFIT","NG_F-FRAME_CC_NEW_RFIT","NG_F-FRAME_CT_NEW_RFIT","NG_H-FRAME_CC_NEW_RFIT"],

                "NaturalGas_CCS":["NG_F-FRAME_CC_95CC_NEW","NG_H-FRAME_CC_95CC_NEW","NG_F-FRAME_CC_97CC_NEW",
                            "NG_H-FRAME_CC_97CC_NEW","NG_CC_EX_RFIT","NG_GT_EX_RFIT","NG_F-FRAME_CC_NEW_RFIT","NG_F-FRAME_CT_NEW_RFIT","NG_H-FRAME_CC_NEW_RFIT"],
                
                "Nuclear":["NUCLEAR-AP1000_NEW","NUCLEAR-SMR_NEW","NUC_ST_EXISTING"],

                "Hydro":["WAT_HY_NEW","WAT_HY_EXISTING"],

                "Solar":["PV-COMMERCIAL","PV-RESIDENTIAL","PV-UTILITY_NEW","SUN_PV_EXISTING"],

                "Wind_ON":["WIND-LAND-C8_NEW","WND_WT_EXISTING","WIND-OFFSHORE-C6_NEW"],

                "Wind_OFF":["COAL_99CC_NEW"],

                "EnergyStorage":["BATT_2H_NEW","BATT_4H_NEW","BATT_6H_NEW",
                                "BATT_8H_NEW","MWH_BA1H_EXISTING","MWH_BA2H_EXISTING",
                                "WAT_PS_EXISTING","WAT_PS_NEW"],

                "Coal/Petrol_ALL":["DFO_CC_EXISTING","DFO_GT_EXISTING","DFO_IC_EXISTING","BIT_ST_EX_NO_RFIT","COAL_NEW","COAL_95CC_NEW","COAL_99CC_NEW",
                                   "BIT_ST_EX_RFIT"]}

# %% [markdown]
# # Determine activity for each group

# %%
def SummarizeActivity(TechAtGroups=TechAtGroups,OutputSqlTables=OutputSqlTables):
    
    df_SummaryFlow=pd.DataFrame(columns=["simulation","scenario","period","period name","group","Activity"])
    
    for i in tqdm(range(len(list(SqliteNamesStochastic.keys())))):
        simulation=list(SqliteNamesStochastic.keys())[i]
        
        Output_VFlow_Out=OutputSqlTables["Output_VFlow_Out"][i]
        scenarios=Output_VFlow_Out["scenario"].unique()

        periods=Output_VFlow_Out["t_periods"].unique()
        periods.sort()
        periods=list(periods)+[2*periods[-1]-periods[-2]]

        PeriodName=[str(periods[i])+"-"+str(periods[i+1]) for i in range(len(periods)-1)]
        periods=periods[:-1]

        

        Groups=list(TechAtGroups.keys())

        for Group in Groups:
            techs=TechAtGroups[Group]

            #Filter for Tech in the group
            df=Output_VFlow_Out[Output_VFlow_Out["tech"].isin(techs)]
            df=df.groupby(["t_periods","scenario"])[["vflow_out"]].sum().reset_index()

            for scenario in scenarios:
                for period in periods:
                    df1=df[(df["scenario"]==scenario) & (df["t_periods"]==period)]

                    df_SummaryFlow_tmp=pd.DataFrame({"simulation":simulation,"scenario":scenario,"period":period,"group":Group,"Activity":df1["vflow_out"],
                                                    "period name":PeriodName[periods.index(period)]})

                    df_SummaryFlow=pd.concat([df_SummaryFlow,df_SummaryFlow_tmp],ignore_index=True)

    return df_SummaryFlow

df_SummaryFlow=SummarizeActivity()
# Out:
# 100%|██████████| 2/2 [01:16<00:00, 38.40s/it]

# %%
df_SummaryFlow_D=SummarizeActivity(TechAtGroups=TechAtGroups,OutputSqlTables=OutputSqlTables_D)
df_SummaryFlow_D=df_SummaryFlow_D.sort_values("period name",ascending=True)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 12.04it/s]

# %% [markdown]
# # Determine the emissions for each group

# %%
def SummarizeEmissions(TechAtGroups=TechAtGroups,OutputSqlTables=OutputSqlTables, emission_name="co2_at"):

    df_SummaryEmissions=pd.DataFrame(columns=["simulation","scenario","period","period name","group","Emissions"])

    for i in tqdm(range(len(list(SqliteNamesStochastic.keys())))):
        simulation=list(SqliteNamesStochastic.keys())[i]
        
        Output_Emissions=OutputSqlTables["Output_Emissions"][i]
        scenarios=Output_Emissions["scenario"].unique()

        periods=Output_Emissions["t_periods"].unique()
        periods.sort()
        periods=list(periods)+[2*periods[-1]-periods[-2]]

        PeriodName=[str(periods[i])+"-"+str(periods[i+1]) for i in range(len(periods)-1)]
        periods=periods[:-1]

        Groups=list(TechAtGroups.keys())

        for Group in Groups:
            techs=TechAtGroups[Group]

            #Filter for Tech in the group
            df=Output_Emissions[Output_Emissions["tech"].isin(techs) * (Output_Emissions["emissions_comm"]==emission_name)]
            df=df.groupby(["t_periods","scenario"])[["emissions"]].sum().reset_index()

            for scenario in scenarios:
                for period in periods:
                    df1=df[(df["scenario"]==scenario) & (df["t_periods"]==period)]

                    df_SummaryEmissions_tmp=pd.DataFrame({"simulation":simulation,"scenario":scenario,"period":period,"group":Group,"Emissions":df1["emissions"],
                                                    "period name":PeriodName[periods.index(period)]})

                    df_SummaryEmissions=pd.concat([df_SummaryEmissions,df_SummaryEmissions_tmp],ignore_index=True)

    return df_SummaryEmissions

df_SummaryEmissions=SummarizeEmissions()
# Out:
# 100%|██████████| 2/2 [00:56<00:00, 28.23s/it]

# %%
df_SummaryEmissions_D=SummarizeActivity(TechAtGroups=TechAtGroups,OutputSqlTables=OutputSqlTables_D)
df_SummaryEmissions_D=df_SummaryEmissions_D.sort_values("period name",ascending=True)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 11.75it/s]

# %%
df_SummaryEmissions=df_SummaryEmissions.sort_values("period name",ascending=True)
df_SummaryFlow=df_SummaryFlow.sort_values("period name",ascending=True)

# %% [markdown]
# # Get Deterministic Data

# %%
X_label="Year"
Y_tabel={"Activity":"TWh/yr","Emissions":"Mt CO2"}
Data={"Activity":df_SummaryFlow,"Emissions":df_SummaryEmissions}

# %%
Iten="Activity" # "Activity" or "Emissions" or "Capacity"
PlotGroups=[]
PlotGroups.append(["Coal/Petrol_ALL","NaturalGas_Non_CCS", "NaturalGas_CCS"])#Line 1
PlotGroups.append(["Solar","Wind_ON", "Wind_OFF"])
PlotGroups.append(["Nuclear","Biomass_CCS", "EnergyStorage"])#Line 2

# %%
################################
Iten="Emissions" # "Activity" or "Emissions" or "Capacity"
PlotGroups=[]
PlotGroups.append(["NaturalGas_Non_CCS", "NaturalGas_CCS"])#Line 1
PlotGroups.append(["Coal/Petrol_ALL","Biomass_CCS"])#Line 2

# %%
NumXplots=len(PlotGroups)
NumYplots=len(PlotGroups[0])
fig, axs = plt.subplots(NumXplots, NumYplots,figsize=(8, 8))

Cases=Data[Iten]["simulation"].unique()
Scenarios=Data[Iten]["scenario"].unique()

Colors=["b","r"]#list(mcolors.BASE_COLORS.keys())
x=Data[Iten]["period name"].unique()

YMax=0
YMin=10*6

#Scale from kt to MT
if Iten=="Emissions":
    Scale=1e-3
else:
    Scale=1


##
Case=Cases[1]
for i in range(NumXplots):
    for j in range(NumYplots):
        group=PlotGroups[i][j]
        y=np.zeros(len(x))

        y_tmp=Data[Iten][(Data[Iten]["group"]==group)]
        y_t=y_tmp["period name"]
        y[[np.where(x==y_t.values[i])[0][0] for i in range(len(y_t.values))]]=y_tmp[Iten].values

        axs[i, j].set_title(group)

        axs[i, j].plot(x, y*Scale, "r-",alpha=0.5,label=Case)
        axs[i, j].set_xticklabels(x, rotation=90)
        YMin=min(YMin,axs[i, j].get_ylim()[0])
        YMax=max(YMax,axs[i, j].get_ylim()[1])


for s in range(len(Scenarios)):
    scenario=Scenarios[s]
    for c in range(1):
        Case=Cases[c]
        for i in range(NumXplots):
            for j in range(NumYplots):
                group=PlotGroups[i][j]
                y=np.zeros(len(x))

                y_tmp=Data[Iten][(Data[Iten]["scenario"]==scenario) & (Data[Iten]["group"]==group)]
                y_t=y_tmp["period name"]
                y[[np.where(x==y_t.values[i])[0][0] for i in range(len(y_t.values))]]=y_tmp[Iten].values

                axs[i, j].set_title(group)

                axs[i, j].plot(x, y*Scale, Colors[c]+"-",alpha=0.5,label=Case)
                axs[i, j].set_xticklabels(x, rotation=90)
                YMin=min(YMin,axs[i, j].get_ylim()[0])
                YMax=max(YMax,axs[i, j].get_ylim()[1])

    if s==0:
        lines_labels = [axs[0, 0].get_legend_handles_labels()]
        lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]

Case=Cases[1]
for i in range(NumXplots):
    for j in range(NumYplots):
        group=PlotGroups[i][j]
        y=np.zeros(len(x))

        y_tmp=Data[Iten][(Data[Iten]["group"]==group)]
        y_t=y_tmp["period name"]
        y[[np.where(x==y_t.values[i])[0][0] for i in range(len(y_t.values))]]=y_tmp[Iten].values

        axs[i, j].set_title(group)

        axs[i, j].plot(x, y*Scale, "r-",label=Case)
        axs[i, j].set_xticklabels(x, rotation=90)
        YMin=min(YMin,axs[i, j].get_ylim()[0])
        YMax=max(YMax,axs[i, j].get_ylim()[1])

for i in range(NumXplots):
    for j in range(NumYplots):
        axs[i,j].set_ylim(YMin, YMax)

plt.yticks(rotation = 95)
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"

for ax in axs.flat:
    ax.label_outer()

fig.supxlabel("Year")
fig.supylabel(Iten+" ("+Y_tabel[Iten]+")")
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

fig.legend(lines, labels=labels,loc="lower center",ncol = 5, bbox_to_anchor=(0.5, -0.05),frameon=False)
# Out:
# C:\Users\Remote\AppData\Local\Temp\ipykernel_10948\726844904.py:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i, j].set_xticklabels(x, rotation=90)
# C:\Users\Remote\AppData\Local\Temp\ipykernel_10948\726844904.py:56: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i, j].set_xticklabels(x, rotation=90)
# C:\Users\Remote\AppData\Local\Temp\ipykernel_10948\726844904.py:77: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i, j].set_xticklabels(x, rotation=90)
# C:\Users\Remote\AppData\Local\Temp\ipykernel_10948\726844904.py:95: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(lines, labels=labels,loc="lower center",ncol = 5, bbox_to_anchor=(0.5, -0.05),frameon=False)

# %% [markdown]
# # Plot the results per period

# %%
def Plot(Iten, PlotGroups, Data=Data):
    NumXplots=len(PlotGroups)
    NumYplots=len(PlotGroups[0])
    fig, axs = plt.subplots(NumXplots, NumYplots,figsize=(8, 8))

    Cases=Data[Iten]["simulation"].unique()
    Scenarios=Data[Iten]["scenario"].unique()

    Colors=["b","r"]#list(mcolors.BASE_COLORS.keys())
    x=Data[Iten]["period name"].unique()

    YMax=0
    YMin=10*6

    #Scale from kt to MT
    if Iten=="Emissions":
        Scale=1e-3
    else:
        Scale=1

    for s in range(len(Scenarios)):
        scenario=Scenarios[s]
        for c in range(len(Cases)):
            Case=Cases[c]
            for i in range(NumXplots):
                for j in range(NumYplots):
                    group=PlotGroups[i][j]
                    y=np.zeros(len(x))

                    y_tmp=Data[Iten][(Data[Iten]["scenario"]==scenario) & (Data[Iten]["group"]==group)]
                    y_t=y_tmp["period name"]
                    y[[np.where(x==y_t.values[i])[0][0] for i in range(len(y_t.values))]]=y_tmp[Iten].values

                    axs[i, j].set_title(group)

                    axs[i, j].plot(x, y*Scale, Colors[c]+"-",alpha=0.5,label=Case)
                    axs[i, j].set_xticklabels(x, rotation=90)
                    YMin=min(YMin,axs[i, j].get_ylim()[0])
                    YMax=max(YMax,axs[i, j].get_ylim()[1])

        if s==0:
            lines_labels = [axs[0, 0].get_legend_handles_labels()]
            lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]

    for i in range(NumXplots):
        for j in range(NumYplots):
            axs[i,j].set_ylim(YMin, YMax)

    plt.yticks(rotation = 95)
    plt.tight_layout() # Or equivalently,  "plt.tight_layout()"

    for ax in axs.flat:
        ax.label_outer()

    fig.supxlabel("Year")
    fig.supylabel(Iten+" ("+Y_tabel[Iten]+")")
    fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

    # lines_labels = [axs[0, 0].get_legend_handles_labels()]
    # lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]

    fig.legend(lines, labels=labels,loc="lower center",ncol = 5, bbox_to_anchor=(0.5, -0.05),frameon=False)

    plt.savefig("Summary_Stochastic"+Iten+".png",dpi=600,bbox_inches='tight')

    return plt.show()

# %%
Iten="Activity" # "Activity" or "Emissions" or "Capacity"
PlotGroups=[]
PlotGroups.append(["Coal/Petrol_ALL","NaturalGas_Non_CCS", "NaturalGas_CCS"])#Line 1
PlotGroups.append(["Solar","Wind_ON", "Wind_OFF"])
PlotGroups.append(["Nuclear","Biomass_CCS", "EnergyStorage"])#Line 2
Plot(Iten,PlotGroups)

################################
# Iten="Capacity" # "Activity" or "Emissions" or "Capacity"
# PlotGroups=[]
# PlotGroups.append(["Coal/Petrol_ALL","NaturalGas_Non_CCS", "NaturalGas_CCS"])#Line 1 
# PlotGroups.append(["Nuclear","Hydro", "Biomass_CCS"])#Line 2
# PlotGroups.append(["Solar","Wind_ON", "EnergyStorage"])
# Plot(Iten,PlotGroups)

################################
Iten="Emissions" # "Activity" or "Emissions" or "Capacity"
PlotGroups=[]
PlotGroups.append(["NaturalGas_Non_CCS", "NaturalGas_CCS"])#Line 1
PlotGroups.append(["Coal/Petrol_ALL","Biomass_CCS"])#Line 2

Plot(Iten,PlotGroups)
# Out:
# C:\Users\Remote\AppData\Local\Temp\ipykernel_10948\2634015601.py:38: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i, j].set_xticklabels(x, rotation=90)
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\Remote\Desktop\Projects\TemoaHurricane_OEA\TEMOA_GIT\TemoaHurricane_V2\InterpretResults\PlotResultsStochastic_TMP.ipynb Cell 18 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> PlotGroups.append(["Solar","Wind_ON", "Wind_OFF"])
#       <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> PlotGroups.append(["Nuclear","Biomass_CCS", "EnergyStorage"])#Line 2
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> Plot(Iten,PlotGroups)
#       <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> ################################
#       <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> # Iten="Capacity" # "Activity" or "Emissions" or "Capacity"
#      <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a> # PlotGroups=[]
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=14'>15</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=15'>16</a> ################################
#      <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=16'>17</a> Iten="Emissions" # "Activity" or "Emissions" or "Capacity"
#
# c:\Users\Remote\Desktop\Projects\TemoaHurricane_OEA\TEMOA_GIT\TemoaHurricane_V2\InterpretResults\PlotResultsStochastic_TMP.ipynb Cell 18 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=57'>58</a> fig.tight_layout() # Or equivalently,  "plt.tight_layout()"
#      <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=59'>60</a> # lines_labels = [axs[0, 0].get_legend_handles_labels()]
#      <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=60'>61</a> # lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=62'>63</a> fig.legend(lines, labels=labels,loc="lower center",ncol = 5, bbox_to_anchor=(0.5, -0.05),frameon=False)
#      <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=64'>65</a> plt.savefig("Summary_Stochastic"+Iten+".png",dpi=600,bbox_inches='tight')
#      <a href='vscode-notebook-cell:/c%3A/Users/Remote/Desktop/Projects/TemoaHurricane_OEA/TEMOA_GIT/TemoaHurricane_V2/InterpretResults/PlotResultsStochastic_TMP.ipynb#X20sZmlsZQ%3D%3D?line=66'>67</a> return plt.show()
#
# UnboundLocalError: cannot access local variable 'lines' where it is not associated with a value

# %% [markdown]
# # Plot the results per hour
